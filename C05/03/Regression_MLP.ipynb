# %% [markdown]
# ## **0. Download dataset**
# **Note:** If you can't download using gdown due to limited number of downloads, please download it manually and upload it to your drive, then copy it from the drive to colab.
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# !cp /path/to/dataset/on/your/drive .
# ```

# %%
# https://drive.google.com/file/d/1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu/view?usp=sharing
# !gdown --id 1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu

# %% [markdown]
# ## **1. Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %% [markdown]
# ## **2. Read dataset**

# %%
dataset_path = 'Auto_MPG_data.csv'
dataset = pd.read_csv(dataset_path)
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0        86.0  2790.0          15.6
# 388  44.0          4          97.0        52.0  2130.0          24.6
# 389  32.0          4         135.0        84.0  2295.0          11.6
# 390  28.0          4         120.0        79.0  2625.0          18.6
# 391  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Europe  Japan  USA
# 0            70       0      0    1
# 1            70       0      0    1
# 2            70       0      0    1
# 3            70       0      0    1
# 4            70       0      0    1
# ..          ...     ...    ...  ...
# 387          82       0      0    1
# 388          82       1      0    0
# 389          82       0      0    1
# 390          82       0      0    1
# 391          82       0      0    1
#
# [392 rows x 10 columns]

# %% [markdown]
# ## **3. Preprocessing data**

# %% [markdown]
# ### **3.1. X, y split**

# %%
X = dataset.drop(columns='MPG').values
y = dataset['MPG'].values

# %% [markdown]
# ### **3.2. Train/val/test split**

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
print(f'Number of training samples: {X_train.shape[0]}')
print(f'Number of val samples: {X_val.shape[0]}')
print(f'Number of test samples: {X_test.shape[0]}')
# Out:
# Number of training samples: 273
# Number of val samples: 79
# Number of test samples: 40

# %% [markdown]
# ### **3.3. Data Normalization**

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %% [markdown]
# ## **4. Create PyTorch DataLoader**

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, 
                          batch_size=batch_size, 
                          shuffle=True)
val_loader = DataLoader(val_dataset, 
                        batch_size=batch_size, 
                        shuffle=False)

# %% [markdown]
# ## **5. Build MLP network**

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.output(x)
        return out.squeeze(1)

# %%
input_dims = X_train.shape[1]
output_dims = 1
hidden_dims = 64

model = MLP(input_dims=input_dims, 
            hidden_dims=hidden_dims, 
            output_dims=output_dims).to(device)

# %%
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %% [markdown]
# ## **6. Training**

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r2_score(train_target, train_predict))
    
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r2_score(val_target, val_predict))
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 282.770	Validation loss: 88.671
#
# EPOCH 2:	Training loss: 137.640	Validation loss: 72.293
#
# EPOCH 3:	Training loss: 71.211	Validation loss: 19.676
#
# EPOCH 4:	Training loss: 24.264	Validation loss: 166.013
#
# EPOCH 5:	Training loss: 89.951	Validation loss: 19.983
#
# EPOCH 6:	Training loss: 17.813	Validation loss: 17.115
#
# EPOCH 7:	Training loss: 20.577	Validation loss: 9.053
#
# EPOCH 8:	Training loss: 38.531	Validation loss: 34.513
#
# EPOCH 9:	Training loss: 19.672	Validation loss: 32.593
#
# EPOCH 10:	Training loss: 21.610	Validation loss: 46.850
#
# EPOCH 11:	Training loss: 32.093	Validation loss: 22.368
#
# EPOCH 12:	Training loss: 10.170	Validation loss: 5.458
#
# EPOCH 13:	Training loss: 15.638	Validation loss: 14.335
#
# EPOCH 14:	Training loss: 12.233	Validation loss: 12.951
#
# EPOCH 15:	Training loss: 14.716	Validation loss: 8.433
#
# EPOCH 16:	Training loss: 10.895	Validation loss: 20.209
#
# EPOCH 17:	Training loss: 12.654	Validation loss: 14.526
#
# EPOCH 18:	Training loss: 15.733	Validation loss: 12.624
#
# EPOCH 19:	Training loss: 14.283	Validation loss: 5.311
#
# EPOCH 20:	Training loss: 7.179	Validation loss: 5.056
#
# EPOCH 21:	Training loss: 8.485	Validation loss: 4.651
#
# EPOCH 22:	Training loss: 6.182	Validation loss: 5.298
#
# EPOCH 23:	Training loss: 10.261	Validation loss: 53.592
#
# EPOCH 24:	Training loss: 11.145	Validation loss: 15.389
#
# EPOCH 25:	Training loss: 9.026	Validation loss: 8.919
#
# EPOCH 26:	Training loss: 10.269	Validation loss: 6.654
#
# EPOCH 27:	Training loss: 6.295	Validation loss: 6.695
#
# EPOCH 28:	Training loss: 10.284	Validation loss: 5.000
#
# EPOCH 29:	Training loss: 6.527	Validation loss: 12.072
#
# EPOCH 30:	Training loss: 18.007	Validation loss: 4.797
#
# EPOCH 31:	Training loss: 7.918	Validation loss: 6.260
#
# EPOCH 32:	Training loss: 7.064	Validation loss: 6.331
#
# EPOCH 33:	Training loss: 7.567	Validation loss: 4.614
#
# EPOCH 34:	Training loss: 6.790	Validation loss: 6.546
#
# EPOCH 35:	Training loss: 7.506	Validation loss: 6.298
#
# EPOCH 36:	Training loss: 6.009	Validation loss: 6.386
#
# EPOCH 37:	Training loss: 6.399	Validation loss: 6.157
#
# EPOCH 38:	Training loss: 7.631	Validation loss: 10.533
#
# EPOCH 39:	Training loss: 7.422	Validation loss: 14.902
#
# EPOCH 40:	Training loss: 7.735	Validation loss: 5.799
#
# EPOCH 41:	Training loss: 5.931	Validation loss: 21.930
#
# EPOCH 42:	Training loss: 8.483	Validation loss: 5.968
#
# EPOCH 43:	Training loss: 7.496	Validation loss: 29.377
#
# EPOCH 44:	Training loss: 10.034	Validation loss: 11.292
#
# EPOCH 45:	Training loss: 6.606	Validation loss: 4.918
#
# EPOCH 46:	Training loss: 8.238	Validation loss: 7.535
#
# EPOCH 47:	Training loss: 6.492	Validation loss: 6.505
#
# EPOCH 48:	Training loss: 5.381	Validation loss: 6.580
#
# EPOCH 49:	Training loss: 6.786	Validation loss: 9.042
#
# EPOCH 50:	Training loss: 6.676	Validation loss: 12.125
#
# EPOCH 51:	Training loss: 8.213	Validation loss: 8.897
#
# EPOCH 52:	Training loss: 10.992	Validation loss: 5.258
#
# EPOCH 53:	Training loss: 7.148	Validation loss: 5.022
#
# EPOCH 54:	Training loss: 6.558	Validation loss: 5.520
#
# EPOCH 55:	Training loss: 5.602	Validation loss: 5.267
#
# EPOCH 56:	Training loss: 5.607	Validation loss: 6.392
#
# EPOCH 57:	Training loss: 7.902	Validation loss: 7.597
#
# EPOCH 58:	Training loss: 7.158	Validation loss: 18.356
#
# EPOCH 59:	Training loss: 7.548	Validation loss: 8.242
#
# EPOCH 60:	Training loss: 5.844	Validation loss: 4.884
#
# EPOCH 61:	Training loss: 5.703	Validation loss: 9.692
#
# EPOCH 62:	Training loss: 11.227	Validation loss: 4.774
#
# EPOCH 63:	Training loss: 6.655	Validation loss: 13.474
#
# EPOCH 64:	Training loss: 6.305	Validation loss: 6.290
#
# EPOCH 65:	Training loss: 8.557	Validation loss: 5.426
#
# EPOCH 66:	Training loss: 5.342	Validation loss: 5.261
#
# EPOCH 67:	Training loss: 5.878	Validation loss: 5.776
#
# EPOCH 68:	Training loss: 9.703	Validation loss: 7.037
#
# EPOCH 69:	Training loss: 7.226	Validation loss: 9.128
#
# EPOCH 70:	Training loss: 6.144	Validation loss: 5.360
#
# EPOCH 71:	Training loss: 5.229	Validation loss: 4.638
#
# EPOCH 72:	Training loss: 5.912	Validation loss: 8.922
#
# EPOCH 73:	Training loss: 6.723	Validation loss: 9.987
#
# EPOCH 74:	Training loss: 6.194	Validation loss: 5.292
#
# EPOCH 75:	Training loss: 5.673	Validation loss: 17.995
#
# EPOCH 76:	Training loss: 7.714	Validation loss: 18.080
#
# EPOCH 77:	Training loss: 11.488	Validation loss: 7.286
#
# EPOCH 78:	Training loss: 6.832	Validation loss: 5.381
#
# EPOCH 79:	Training loss: 6.022	Validation loss: 11.591
#
# EPOCH 80:	Training loss: 8.155	Validation loss: 5.869
#
# EPOCH 81:	Training loss: 11.042	Validation loss: 6.224
#
# EPOCH 82:	Training loss: 5.845	Validation loss: 5.694
#
# EPOCH 83:	Training loss: 5.529	Validation loss: 8.500
#
# EPOCH 84:	Training loss: 5.463	Validation loss: 5.088
#
# EPOCH 85:	Training loss: 5.064	Validation loss: 6.670
#
# EPOCH 86:	Training loss: 4.836	Validation loss: 6.360
#
# EPOCH 87:	Training loss: 5.126	Validation loss: 6.791
#
# EPOCH 88:	Training loss: 5.152	Validation loss: 5.220
#
# EPOCH 89:	Training loss: 4.934	Validation loss: 5.325
#
# EPOCH 90:	Training loss: 6.716	Validation loss: 6.105
#
# EPOCH 91:	Training loss: 5.365	Validation loss: 7.294
#
# EPOCH 92:	Training loss: 7.103	Validation loss: 5.287
#
# EPOCH 93:	Training loss: 6.134	Validation loss: 5.111
#
# EPOCH 94:	Training loss: 9.026	Validation loss: 7.445
#
# EPOCH 95:	Training loss: 6.266	Validation loss: 6.454
#
# EPOCH 96:	Training loss: 8.622	Validation loss: 20.126
#
# EPOCH 97:	Training loss: 7.224	Validation loss: 10.064
#
# EPOCH 98:	Training loss: 6.788	Validation loss: 8.391
#
# EPOCH 99:	Training loss: 6.243	Validation loss: 5.193
#
# EPOCH 100:	Training loss: 5.896	Validation loss: 4.890

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_r2, color='green')
ax[1, 0].set(xlabel='Epoch', ylabel='R2')
ax[1, 0].set_title('Training R2')

ax[1, 1].plot(val_r2, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='R2')
ax[1, 1].set_title('Validation R2')

plt.show()

# %% [markdown]
# ## **7. Evaluation**

# %%
model.eval()
with torch.no_grad():
    y_hat = model(X_val)
    val_set_r2 = r2_score(y_hat, y_val)
    print('Evaluation on validation set:')
    print(f'R2: {val_set_r2}')
# Out:
# Evaluation on validation set:
# R2: 0.8898899185785232
